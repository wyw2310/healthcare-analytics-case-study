# %% [markdown]
# # 🏥 SJGHC Hospital Episode Analysis – Reproducible Workflow
#
# ## 1. Introduction
# This notebook analyzes hospital episode data from St John of God Health Care (SJGHC).
# The goal is to uncover operational, financial, and referral-based insights that support
# better patient care, resource allocation, and cost containment strategies.

# %%
# 📦 Functions

import os
import pandas as pd

def load_or_create_df(version="raw", excel_path=None, sheet_name=0):
    """
    Loads a versioned pickle file if it exists.
    If not, loads from Excel and saves the pickle for future use.
    
    Parameters:
    - version: str, one of ["raw", "cleansed", "transformed"]
    - excel_path: str, path to Excel file (required if pickle doesn't exist)
    - sheet_name: str or int, sheet name or index in Excel file
    
    Returns:
    - df: pandas DataFrame
    """
    pickle_path = f"../data/staging/hcp_{version}.pkl"
    
    if os.path.exists(pickle_path):
        print(f"✅ Loading '{version}' version from pickle...")
        df = pd.read_pickle(pickle_path)
    else:
        if not excel_path:
            raise ValueError("Excel path must be provided if pickle doesn't exist.")
        print(f"⚠️ Pickle not found. Loading from Excel and saving as '{version}'...")
        df = pd.read_excel(excel_path, sheet_name=sheet_name)
        df.to_pickle(pickle_path)
    
    return df

# %% [markdown]
# ## 2. Data Import

# %%
# 🚀 Main Workflow

# Load the raw version of the dataset
df = load_or_create_df(
    version="raw",
    excel_path="../data/raw/HCP Dataset for Case Study.xlsx",
    sheet_name="Sheet1"
)

# Preview the data
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 df = pd.read_excel("../data/raw/HCP Dataset for Case Study.xlsx")
#       4 # Save the DataFrame as a pickle file for fast reload
#       5 df.to_pickle("../data/staging/hcp_df.pkl")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#     464 try:
# --> 465     data = io.parse(
#     466         sheet_name=sheet_name,
#     467         header=header,
#     468         names=names,
#     469         index_col=index_col,
#     470         usecols=usecols,
#     471         squeeze=squeeze,
#     472         dtype=dtype,
#     473         converters=converters,
#     474         true_values=true_values,
#     475         false_values=false_values,
#     476         skiprows=skiprows,
#     477         nrows=nrows,
#     478         na_values=na_values,
#     479         keep_default_na=keep_default_na,
#     480         na_filter=na_filter,
#     481         verbose=verbose,
#     482         parse_dates=parse_dates,
#     483         date_parser=date_parser,
#     484         thousands=thousands,
#     485         decimal=decimal,
#     486         comment=comment,
#     487         skipfooter=skipfooter,
#     488         convert_float=convert_float,
#     489         mangle_dupe_cols=mangle_dupe_cols,
#     490     )
#     491 finally:
#     492     # make sure to close opened file handles
#     493     if should_close:
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1424 def parse(
#    1425     self,
#    1426     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1445     **kwds,
#    1446 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1447     """
#    1448     Parse specified sheet(s) into a DataFrame.
#    1449
#    (...)
#    1456         DataFrame from the passed in Excel file.
#    1457     """
# -> 1458     return self._reader.parse(
#    1459         sheet_name=sheet_name,
#    1460         header=header,
#    1461         names=names,
#    1462         index_col=index_col,
#    1463         usecols=usecols,
#    1464         squeeze=squeeze,
#    1465         converters=converters,
#    1466         true_values=true_values,
#    1467         false_values=false_values,
#    1468         skiprows=skiprows,
#    1469         nrows=nrows,
#    1470         na_values=na_values,
#    1471         parse_dates=parse_dates,
#    1472         date_parser=date_parser,
#    1473         thousands=thousands,
#    1474         comment=comment,
#    1475         skipfooter=skipfooter,
#    1476         convert_float=convert_float,
#    1477         mangle_dupe_cols=mangle_dupe_cols,
#    1478         **kwds,
#    1479     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:638, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     635 else:  # assume an integer if not a string
#     636     sheet = self.get_sheet_by_index(asheetname)
# --> 638 data = self.get_sheet_data(sheet, convert_float)
#     639 if hasattr(sheet, "close"):
#     640     # pyxlsb opens two TemporaryFiles
#     641     sheet.close()
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:575, in OpenpyxlReader.get_sheet_data(self, sheet, convert_float)
#     573 data: list[list[Scalar]] = []
#     574 last_row_with_data = -1
# --> 575 for row_number, row in enumerate(sheet.rows):
#     576     converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     577     while converted_row and converted_row[-1] == "":
#     578         # trim trailing empty elements
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      75 src = self._get_source()
#      76 parser = WorkSheetParser(src, self._shared_strings,
#      77                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                          date_formats=self.parent._date_formats)
# ---> 79 for idx, row in parser.parse():
#      80     if max_row is not None and idx > max_row:
#      81         break
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:155, in WorkSheetParser.parse(self)
#     153     element.clear()
#     154 elif tag_name == ROW_TAG:
# --> 155     row = self.parse_row(element)
#     156     element.clear()
#     157     yield row
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:286, in WorkSheetParser.parse_row(self, row)
#     282 if keys - {'r', 'spans'}:
#     283     # don't create dimension objects unless they have relevant information
#     284     self.row_dimensions[str(self.row_counter)] = attrs
# --> 286 cells = [self.parse_cell(el) for el in row]
#     287 return self.row_counter, cells
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:286, in <listcomp>(.0)
#     282 if keys - {'r', 'spans'}:
#     283     # don't create dimension objects unless they have relevant information
#     284     self.row_dimensions[str(self.row_counter)] = attrs
# --> 286 cells = [self.parse_cell(el) for el in row]
#     287 return self.row_counter, cells
#
# File ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:178, in WorkSheetParser.parse_cell(self, element)
#     177 def parse_cell(self, element):
# --> 178     data_type = element.get('t', 'n')
#     179     coordinate = element.get('r')
#     180     style_id = element.get('s', 0)
#
# KeyboardInterrupt:

# %%
# Load from pickle (much faster than Excel)
df = pd.read_pickle("../data/staging/hcp_df.pkl")
df.head()

# %% [markdown]
# ## 3. Feature Engineering – Episode Duration & Charge Per Day

# %%
# Convert dates to datetime format
df["AdmissionDate"] = pd.to_datetime(df["AdmissionDate"])
df["DischargeDate"] = pd.to_datetime(df["DischargeDate"])

# Calculate episode duration in days
df["EpisodeDuration"] = (df["DischargeDate"] - df["AdmissionDate"]).dt.days + 1

# Calculate charge per day
df["ChargePerDay"] = df["ChargeAmount"] / df["EpisodeDuration"]

# Preview the new columns
df[["EpisodeID", "EpisodeDuration", "ChargeAmount", "ChargePerDay"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DischargeDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 # Convert dates to datetime format
#       2 df["AdmissionDate"] = pd.to_datetime(df["AdmissionDate"])
# ----> 3 df["DischargeDate"] = pd.to_datetime(df["DischargeDate"])
#       5 # Calculate episode duration in days
#       6 df["EpisodeDuration"] = (df["DischargeDate"] - df["AdmissionDate"]).dt.days + 1
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'DischargeDate'

# %% [markdown]
# # 4. Feature Engineering – Referral Source Flags

# %%
# Create binary flags for key referral sources
df["IsEmergencyReferral"] = df["ReferralSource"].str.contains("Emergency", case=False)
df["IsExternalGPReferral"] = df["ReferralSource"].str.contains("External GP", case=False)

# Preview the new flags
df[["EpisodeID", "ReferralSource", "IsEmergencyReferral", "IsExternalGPReferral"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # Create binary flags for key referral sources
# ----> 2 df["IsEmergencyReferral"] = df["ReferralSource"].str.contains("Emergency", case=False)
#       3 df["IsExternalGPReferral"] = df["ReferralSource"].str.contains("External GP", case=False)
#       5 # Preview the new flags
#
# NameError: name 'df' is not defined
